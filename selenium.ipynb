# %%
df[" "]=index
df.set_index(" ",inplace=True)
df
# Out:
#      call_oi call_chng_in_oi call_volume call_iv call_ltp call_chng  \
#
#          928             -39          47       -  2916.15    176.15
#            2               -           -       -   2235.7         -
#            6              -1           5       -   2821.9     216.4
#            1               -           -       -  2613.85         -
#         9949            -699         979       -   2722.3    130.35
#            2              -1           6       -   2577.9      62.8
#           12               3           9       -  2618.25     211.7
#            2               -           -       -  2353.55         -
#           18              -1          10       -  2507.65     202.1
#            6               -           4       -   2424.4     129.4
#          142               -           9       -  2371.15    106.15
#           13               -           4       -  2319.45     122.1
#           79               1           4       -   2309.8     159.8
# ...
